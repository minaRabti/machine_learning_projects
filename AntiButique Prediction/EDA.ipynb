# %%
import pandas as pd
import numpy as np

#visulization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_excel('sheet1.xlsx')
data1
# Out:
#     ATC-3（n=9） ATC-4（n=31）                           drug（n=173）
# 0         J01A       J01AA                           Doxycycline
# 1         J01A       J01AA                          Guamecycline
# 2         J01A       J01AA                           Metacycline
# 3         J01A       J01AA                           Minocycline
# 4         J01A       J01AA                          Tetracycline
# ..         ...         ...                                   ...
# 168       J01X       J01XX                             Linezolid
# 169       J01X       J01XX                            Fosfomycin
# 170       J01X       J01XX                    Fosfomycin Calcium
# 171       J01X       J01XX  Fosfomycin Calcium and Trimethoprim
# 172       J01X       J01XX                           Methenamine
#
# [173 rows x 3 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ATC-3（n=9）   173 non-null    object
#  1   ATC-4（n=31）  173 non-null    object
#  2   drug（n=173）  173 non-null    object
# dtypes: object(3)
# memory usage: 4.2+ KB

# %%
#no missing data

data1.isnull().sum()
# Out:
# ATC-3（n=9）     0
# ATC-4（n=31）    0
# drug（n=173）    0
# dtype: int64

# %%
data1['drug（n=173）'].value_counts()
# Out:
# Spiramycin                                 2
# Mezlocillin Sodium and Sulbactam Sodium    1
# Tetracycline                               1
# Cefaclor                                   1
# Azlocillin Sodium                          1
#                                           ..
# Cefpodoxime Proxetil                       1
# Compound Cefaclor                          1
# Fosfomycin Calcium                         1
# Josamycin                                  1
# Streptomycin                               1
# Name: drug（n=173）, Length: 172, dtype: int64

# %%
data1['ATC-4（n=31）'].value_counts()
# Out:
# J01DD       21
# J01MA       19
# J01FA       15
# J01CR       13
# J01DC       11
# J01GB       10
# J01DB       10
# J01CA        8
# J01XX        7
# J01AA        7
# J01CE        6
# J01XD        5
# J01DH        5
# J01CF        4
# J01DE        4
# J01EC        3
# J01FF        3
# J01XA        3
# J01BA        3
# J01EB        2
# J01EE        2
# J01XE        2
# J01FG        2
# J01XB        1
# J01GA        1
# J01EA        1
# J01CG        1
# J01XC        1
# J01DA        1
# J01DI        1
# J01DF        1
# Name: ATC-4（n=31）, dtype: int64

# %%
data1['ATC-3（n=9）'].value_counts()
# Out:
# J01D    54
# J01C    32
# J01F    20
# J01M    19
# J01X    19
# J01G    11
# J01E     8
# J01A     7
# J01B     3
# Name: ATC-3（n=9）, dtype: int64

# %%
#detect duplicate
data1.duplicated().sum()
# Out:
# 1

# %%
#remove duplicate

data1.drop_duplicates(inplace=True)

data1.shape
# Out:
# (172, 3)

# %%
data1.columns
# Out:
# Index(['ATC-3（n=9）', 'ATC-4（n=31）', 'drug（n=173）'], dtype='object')

# %%
data1.columns=[column.replace(' ','') for column in data1.columns]
data1.head()
# Out:
#   ATC-3（n=9） ATC-4（n=31）   drug（n=173）
# 0       J01A       J01AA   Doxycycline
# 1       J01A       J01AA  Guamecycline
# 2       J01A       J01AA   Metacycline
# 3       J01A       J01AA   Minocycline
# 4       J01A       J01AA  Tetracycline

# %%
data1.groupby('drug（n=173）').sum()
# Out:
#                                      ATC-3（n=9） ATC-4（n=31）
# drug（n=173）
# Acetylkitasamycin                          J01F       J01FG
# Acetylspiramycin                           J01F       J01FA
# Amikacin                                   J01G       J01GB
# Amikacini Sulfatis                         J01G       J01GB
# Amoxiciliin and Clavulanate Potassiu       J01C       J01CR
# ...                                         ...         ...
# Tinidazole                                 J01X       J01XD
# Tobramycin                                 J01G       J01GB
# Tosufloxacin                               J01M       J01MA
# Trimethoprim                               J01E       J01EA
# Vancomycin                                 J01X       J01XA
#
# [172 rows x 2 columns]

# %%
data1_group = data1.groupby(['ATC-3（n=9）' ,'ATC-4（n=31）' ]).sum()
data1_group
# Out:
#                                                               drug（n=173）
# ATC-3（n=9） ATC-4（n=31）
# J01A       J01AA        DoxycyclineGuamecyclineMetacyclineMinocyclineT...
# J01B       J01BA        Thiamphenicol Thiamphenicol GlycinateChloramph...
# J01C       J01CA        Azlocillin SodiumAmoxicillinAmpicillinFurbenic...
#            J01CE        Benzathine penicillinNafcillin SodiumProcaine ...
#            J01CF        Oxacillin SodiumFlucloxacillin SodiumLenampici...
#            J01CG                                        Sulbactam Sodium
#            J01CR        Amoxicillin and FlucloxacillinAmoxiciliin and ...
# J01D       J01DA                                        Cefetamet Pivoxil
#            J01DB        CefalexinCefalexin and Trimethoprin CefradineC...
#            J01DC        Compound CefaclorCefprozilCefuroxime SodiumCef...
#            J01DD        Latamoxef SodiumCefpodoxime ProxetilCeftibuten...
# ...

# %%
data2 = pd.read_excel('sheet2.xlsx')
data2
# Out:
#           Province  simple_hospital  hos_2011  hos_2012  hos_2013  hos_2014  \
# 0            Anhui                7        35        36        37        53
# 1          Beijing               31        50        50        62        68
# 2           Fujian               19        40        52        53        52
# 3            Gansu                1        30        34        35        35
# 4        Guangdong               52        90       105       117       128
# 5          Guangxi                2        49        50        53        55
# 6          Guizhou                7        24        38        40        44
# 7            Hebei               15        43        55        56        58
# 8            Henan               17        55        85        82        85
# 9      Helongjiang               28        70        77        77        82
# 10           Hubei               29        60        60        68        83
# ...

# %%
data2.shape
# Out:
# (28, 12)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Province         28 non-null     object
#  1   simple_hospital  28 non-null     int64
#  2   hos_2011         28 non-null     int64
#  3   hos_2012         28 non-null     int64
#  4   hos_2013         28 non-null     int64
#  5   hos_2014         28 non-null     int64
#  6   hos_2015         28 non-null     int64
#  7   prop_2011        28 non-null     float64
#  8   prop_2012        28 non-null     float64
#  9   prop_2013        28 non-null     float64
#  10  prop_2014        28 non-null     float64
#  11  prop_2015        28 non-null     float64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 2.8+ KB

# %%
data2.isnull().sum()
# Out:
# Province           0
# simple_hospital    0
# hos_2011           0
# hos_2012           0
# hos_2013           0
# hos_2014           0
# hos_2015           0
# prop_2011          0
# prop_2012          0
# prop_2013          0
# prop_2014          0
# prop_2015          0
# dtype: int64

# %%
data2.duplicated().sum()
# Out:
# 0

# %%
data2.describe()
# Out:
#        simple_hospital   hos_2011    hos_2012    hos_2013    hos_2014  \
# count        28.000000  28.000000   28.000000   28.000000   28.000000
# mean         16.714286  47.571429   54.750000   59.464286   64.750000
# std          11.658274  22.366358   26.857132   29.765108   33.595221
# min           1.000000   4.000000    4.000000    5.000000    7.000000
# 25%           7.000000  33.750000   37.750000   41.500000   44.000000
# 50%          16.500000  44.500000   49.000000   51.000000   52.500000
# 75%          24.250000  61.750000   77.000000   78.250000   83.500000
# max          52.000000  90.000000  105.000000  117.000000  128.000000
#
#          hos_2015  prop_2011  prop_2012  prop_2013  prop_2014  prop_2015
# count   28.000000  28.000000  28.000000  28.000000  28.000000  28.000000
# mean    68.964286   0.352428   0.310653   0.284805   0.264172   0.245434
# std     35.501155   0.208459   0.192104   0.174939   0.169337   0.150934
# ...

# %%
data3 = pd.read_excel('sheet3.xlsx')
data3
# Out:
#           province   population_2011   population_2012   population_2013  \
# 0            Anhui          59680000          59880000          60300000
# 1          Beijing          20190000          20690000          21150000
# 2           Fujian          37200000          37480000          37740000
# 3            Gansu          25640000          25780000          25820000
# 4        Guangdong         105050000         105940000         106440000
# 5          Guangxi          46450000          46820000          47190000
# 6          Guizhou          34690000          34840000          35020000
# 7            Hebei          72410000          72880000          73330000
# 8            Henan          93880000          94060000          94130000
# 9      Helongjiang          38340000          38340000          38350000
# 10           Hubei          57580000          57790000          57990000
# 11           Hunan          65960000          66390000          66910000
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   province                   28 non-null     object
#  1    population_2011           28 non-null     int64
#  2    population_2012           28 non-null     int64
#  3    population_2013           28 non-null     int64
#  4    population_2014           28 non-null     int64
#  5    population_2015           28 non-null     int64
#  6   admission_hos_2011         28 non-null     float64
#  7   admission_hos_2012         28 non-null     float64
#  8   admission_hos_2013         28 non-null     float64
#  9   admission_hos_2014         28 non-null     float64
#  10  admission_hos_2015         28 non-null     float64
#  11  Coverage_population _2011  28 non-null     float64
#  12  Coverage_population _2012  28 non-null     float64
# ...

# %%
data3.describe()
# Out:
#         population_2011   population_2012   population_2013   population_2014  \
# count      2.800000e+01      2.800000e+01      2.800000e+01      2.800000e+01
# mean       4.724786e+07      4.750750e+07      4.776107e+07      4.801500e+07
# std        2.606544e+07      2.614490e+07      2.619482e+07      2.630744e+07
# min        6.390000e+06      6.470000e+06      6.540000e+06      6.620000e+06
# 25%        2.702750e+07      2.707000e+07      2.708750e+07      2.711750e+07
# 50%        4.108500e+07      4.111500e+07      4.112500e+07      4.112000e+07
# 75%        6.125000e+07      6.150750e+07      6.195250e+07      6.246500e+07
# max        1.050500e+08      1.059400e+08      1.064400e+08      1.072400e+08
#
#         population_2015  admission_hos_2011  admission_hos_2012  \
# count      2.800000e+01        2.800000e+01        2.800000e+01
# mean       4.830893e+07        8.742851e+06        9.950997e+06
# std        2.649963e+07        6.194475e+06        6.912258e+06
# ...

# %%
data3.duplicated().sum()
# Out:
# 0

# %%
data4 = pd.read_excel('sheet4.xlsx')
data4
# Out:
#   Unnamed: 0  DDD_sam_hos_2011_1  DDD_sam_hos_2011_2  DDD_sam_hos_2011_3  \
# 0       J01A        8.084320e+05          616620.000        8.027550e+05
# 1       J01B        8.217800e+04           45122.249        8.642358e+04
# 2       J01C        1.317138e+07         6687186.072        8.594179e+06
# 3       J01D        1.658930e+07         9121358.832        1.318982e+07
# 4       J01E        1.252445e+05           66476.741        7.875499e+04
# 5       J01F        7.905437e+06         4538117.818        6.127445e+06
# 6       J01G        1.071340e+06          540794.451        7.374910e+05
# 7       J01M        5.763454e+06         3398760.750        5.051867e+06
# 8       J01X        4.856060e+06         2528354.468        3.415143e+06
#
#    DDD_sam_hos_2011_4  DDD_sam_hos_2011_5  DDD_sam_hos_2011_6  \
# 0        7.367257e+05        1.038556e+06        7.238450e+05
# 1        9.256167e+04        7.352033e+04        7.429350e+04
# ...

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Columns: 121 entries, Unnamed: 0 to DID_sam_hos_2015_12
# dtypes: float64(120), object(1)
# memory usage: 8.6+ KB

# %%
data4.isnull().sum().sort_values(ascending= False)
# Out:
# DID_sam_hos_2015_12    0
# DDD_sam_hos_2015_11    0
# DDD_sam_hos_2013_7     0
# DDD_sam_hos_2013_8     0
# DDD_sam_hos_2013_9     0
#                       ..
# DID_sam_hos_2012_12    0
# DID_sam_hos_2013_1     0
# DID_sam_hos_2013_2     0
# DID_sam_hos_2013_3     0
# Unnamed: 0             0
# Length: 121, dtype: int64

# %%
data5 = pd.read_excel('sheet5.xlsx')
data5
# Out:
#    province  DDD_sam_hos_2011_1  DDD_sam_hos_2011_2  DDD_sam_hos_2011_3  \
# 0     J01AA          808432.000          616620.000          802755.000
# 1     J01BA           82178.000           45122.249           86423.583
# 2     J01CA         2293639.733         1157493.301         1548117.088
# 3     J01CE         1581290.866          696282.870         1330648.932
# 4     J01CF          127553.930           61136.109           90434.895
# 5     J01CG            5972.500            2862.500            7289.500
# 6     J01CR         9162924.181         4769411.292         5617689.068
# 7     J01DA          406202.703          197234.987          329457.313
# 8     J01DB         2058451.515         1104342.020         1533168.023
# 9     J01DC         7040602.997         3834669.059         5369482.610
# 10    J01DD         6032657.597         3377467.094         5093437.724
# 11    J01DE          394812.290          213818.791          302455.411
# ...

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Columns: 121 entries, province to DID_sam_hos_2015_12
# dtypes: float64(120), object(1)
# memory usage: 29.4+ KB

# %%
data5 = data5.replace(to_replace =data5["DDD_sam_hos_2011_8"][15], value =np.nan)

# %%
data5 = data5.replace(to_replace =data5["DDD_sam_hos_2011_11"][18], value =np.nan)
data5 = data5.replace(to_replace =data5["DDD_sam_hos_2011_11"][26], value =np.nan)

data5 = data5.replace(to_replace =data5["DDD_sam_hos_2012_1"][29], value =np.nan)

# %%
data5.describe()
# Out:
#        DDD_sam_hos_2011_1  DDD_sam_hos_2011_2  DDD_sam_hos_2011_3  \
# count        3.100000e+01        3.100000e+01        3.100000e+01
# mean         1.624930e+06        8.884771e+05        1.228512e+06
# std          2.602449e+06        1.428321e+06        1.928925e+06
# min          3.923330e+02        1.666700e+01        1.000000e+02
# 25%          6.751900e+04        4.276112e+04        5.977525e+04
# 50%          3.688472e+05        1.972350e+05        2.947976e+05
# 75%          1.819871e+06        9.432544e+05        1.442280e+06
# max          9.162924e+06        4.769411e+06        5.786753e+06
#
#        DDD_sam_hos_2011_4  DDD_sam_hos_2011_5  DDD_sam_hos_2011_6  \
# count        3.000000e+01        3.100000e+01        3.100000e+01
# mean         1.486165e+06        1.207970e+06        1.138429e+06
# std          2.333633e+06        1.840658e+06        1.749808e+06
# min          5.666700e+01        9.700000e+01        1.516670e+02
# ...

# %%
data5.isnull().sum().sort_values(ascending= False)
# Out:
# DDD_sam_hos_2015_10    3
# DDD_sam_hos_2014_1     3
# DDD_sam_hos_2015_9     3
# DDD_sam_hos_2015_7     3
# DDD_sam_hos_2013_4     3
#                       ..
# DID_sam_hos_2012_12    0
# DID_sam_hos_2013_1     0
# DID_sam_hos_2013_2     0
# DID_sam_hos_2013_3     0
# province               0
# Length: 121, dtype: int64

# %%
data5=data5.interpolate(method ='linear', limit_direction ='forward')
data5.isnull().sum()
# Out:
# province               0
# DDD_sam_hos_2011_1     0
# DDD_sam_hos_2011_2     0
# DDD_sam_hos_2011_3     0
# DDD_sam_hos_2011_4     0
#                       ..
# DID_sam_hos_2015_8     0
# DID_sam_hos_2015_9     0
# DID_sam_hos_2015_10    0
# DID_sam_hos_2015_11    0
# DID_sam_hos_2015_12    0
# Length: 121, dtype: int64

# %%
data5
# Out:
#    province  DDD_sam_hos_2011_1  DDD_sam_hos_2011_2  DDD_sam_hos_2011_3  \
# 0     J01AA          808432.000          616620.000          802755.000
# 1     J01BA           82178.000           45122.249           86423.583
# 2     J01CA         2293639.733         1157493.301         1548117.088
# 3     J01CE         1581290.866          696282.870         1330648.932
# 4     J01CF          127553.930           61136.109           90434.895
# 5     J01CG            5972.500            2862.500            7289.500
# 6     J01CR         9162924.181         4769411.292         5617689.068
# 7     J01DA          406202.703          197234.987          329457.313
# 8     J01DB         2058451.515         1104342.020         1533168.023
# 9     J01DC         7040602.997         3834669.059         5369482.610
# 10    J01DD         6032657.597         3377467.094         5093437.724
# 11    J01DE          394812.290          213818.791          302455.411
# ...

# %%
data6_1 = pd.read_excel('sheet6_1.xlsx')
data6_1
# Out:
#   Unnamed: 0  Coverage_ population_2011  Coverage_ population_2012  \
# 0       east                7712.757768                7342.796792
# 1    central                5046.025208                4729.097596
# 2       west                3033.045521                2747.185703
#
#    Coverage_ population_2013  Coverage_ population_2014  \
# 0                6905.967719                6873.095251
# 1                4736.560590                4423.301151
# 2                2721.572760                2635.741149
#
#    Coverage_ population_2015  Coverage_inpatient _2011  \
# 0                6589.953930               6047.033598
# 1                4452.049240               2019.890050
# 2                2511.082571               1275.553713
#
#    Coverage_inpatient _2012  Coverage_inpatient _2013  \
# 0               6032.262801               5773.936354
# 1               2008.934439               1680.259827
# 2               1261.535118               1311.958871
#
# ...

# %%
data6_1.info()
